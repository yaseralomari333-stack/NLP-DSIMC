# %% [markdown]
# <a href="https://colab.research.google.com/github/yaseralomari333-stack/NLP-DSIMC/blob/main/NLP-DSIMC0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 2) تحميل الكود من GitHub على Colab فقط
# !rm -rf /content/NLP-DSIMC
# !git clone https://github.com/yaseralomari333-stack/NLP-DSIMC.git /content/NLP-DSIMC

# %cd /content/NLP-DSIMC
# !ls
# Out:
# Cloning into '/content/NLP-DSIMC'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 26 (delta 0), reused 23 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 22.09 KiB | 611.00 KiB/s, done.
# /content/NLP-DSIMC
# colab_run.ipynb  Models     requirements.txt  _smoke_test.py
# DAL		 README.md  RUN.py

# %%
# 3) تثبيت المتطلبات
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: openpyxl>=3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: scikit-learn>=1.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: joblib>=1.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: transformers>=4.36 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (5.0.0)
# Requirement already satisfied: datasets>=2.14 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: accelerate>=0.25 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.13.0)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.10.0+cpu)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2026.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->-r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 6)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 6)) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36->-r requirements.txt (line 7)) (4.67.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14->-r requirements.txt (line 8)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14->-r requirements.txt (line 8)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14->-r requirements.txt (line 8)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14->-r requirements.txt (line 8)) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (2025.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.25->-r requirements.txt (line 9)) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 10)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 10)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 10)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 10)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (0.24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14->-r requirements.txt (line 8)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14->-r requirements.txt (line 8)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14->-r requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.14->-r requirements.txt (line 8)) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14->-r requirements.txt (line 8)) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.36->-r requirements.txt (line 7)) (0.1.2)

# %%
# 4) نسخ الداتاست من Drive إلى Colab
# هيك الداتاست بتصير موجودة على Colab، مش بنشتغل مباشرة من Drive

import os, shutil

drive_dataset_path = "/content/drive/MyDrive/Arabic Suicidal Dataset/Arabic Suicidal Dataset.xlsx"

if not os.path.exists(drive_dataset_path):
    matches = []
    for root, dirs, files in os.walk("/content/drive/MyDrive"):
        for file in files:
            if "suicidal" in file.lower() and file.lower().endswith((".xlsx", ".csv")):
                matches.append(os.path.join(root, file))

    if not matches:
        raise FileNotFoundError("لم أجد ملف الداتاست في Google Drive")

    drive_dataset_path = matches[0]

local_data_dir = "/content/NLP-DSIMC/DAL"
os.makedirs(local_data_dir, exist_ok=True)

local_dataset_path = os.path.join(local_data_dir, os.path.basename(drive_dataset_path))
shutil.copy2(drive_dataset_path, local_dataset_path)

print("Dataset copied to Colab:")
print(local_dataset_path)
# Out:
# Dataset copied to Colab:
# /content/NLP-DSIMC/DAL/Arabic Suicidal Dataset.xlsx

# %%
# 5) إنشاء مجلد نتائج على Colab فقط
import os

OUTPUT_DIR = "/content/outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

print("Reports/results will be saved here:")
print(OUTPUT_DIR)
# Out:
# Reports/results will be saved here:
# /content/outputs

# %%
# 6) تشغيل المشروع وحفظ كل النتائج على Colab فقط

import os

OUTPUT_DIR = "/content/outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# هذا بخلي artifacts تنحفظ في /content/outputs بدل Drive
os.environ["NLP_ARTIFACTS_DIR"] = OUTPUT_DIR
# %env NLP_ARTIFACTS_DIR=/content/outputs

# %cd /content/NLP-DSIMC

# شغّل كل المشروع
# !python RUN.py all --data "{local_dataset_path}" --fp16
# Out:
# env: NLP_ARTIFACTS_DIR=/content/outputs
# /content/NLP-DSIMC
#
# ========== STEP 1/4 : EDA ==========
# {
#   "text_col": "text",
#   "label_col": "Label",
#   "n_rows": 5717,
#   "files": [
#     "/content/outputs/eda/05_dataset_overview.txt",
#     "/content/outputs/eda/01_class_balance.png",
#     "/content/outputs/eda/02_text_length_hist.png",
#     "/content/outputs/eda/03_text_length_box.png",
#     "/content/outputs/eda/04_top_tokens_not.png",
#     "/content/outputs/eda/04_top_tokens_s.png"
#   ]
# }
#
# ========== STEP 2/4 : BASELINES ==========
# Train=4115  Val=458  Test=1144  Classes=['not', 's']
#
# >>> Training baseline: svm
# {
#   "model": "svm",
#   "accuracy": 0.8426573426573427,
#   "precision_macro": 0.7880675467941212,
#   "recall_macro": 0.8084757878397975,
#   "f1_macro": 0.7971175559522825,
#   "f1_weighted": 0.8453460385513684
# }
#
# >>> Training baseline: logreg
# {
#   "model": "logreg",
#   "accuracy": 0.8304195804195804,
#   "precision_macro": 0.7737516570923553,
#   "recall_macro": 0.8061883463023098,
#   "f1_macro": 0.7866845057534899,
#   "f1_weighted": 0.8351476965996983
# }
#
# >>> Training baseline: rf
# {
#   "model": "rf",
#   "accuracy": 0.8461538461538461,
#   "precision_macro": 0.8056076550456964,
#   "recall_macro": 0.7615668974531788,
#   "f1_macro": 0.7791883628196299,
#   "f1_weighted": 0.8402013587463603
# }
#
# Saved -> /content/outputs/baseline_metrics.json
#
# ========== STEP 3/4 : MARBERT ==========
# Train=4115  Val=458  Test=1144  Classes=['not', 's']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 701/701 [00:00<00:00, 1.35MB/s]
# tokenizer_config.json: 100% 376/376 [00:00<00:00, 1.45MB/s]
# vocab.txt: 1.10MB [00:00, 24.0MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 504kB/s]
# pytorch_model.bin: 100% 654M/654M [00:12<00:00, 52.6MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 1062.86it/s, Materializing param=bert.pooler.dense.weight]
# BertForSequenceClassification LOAD REPORT from: UBC-NLP/MARBERT
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors: 100% 654M/654M [00:08<00:00, 77.6MB/s]
# Map: 100% 4115/4115 [00:00<00:00, 7266.61 examples/s]
# Map: 100% 458/458 [00:00<00:00, 7587.54 examples/s]
# Traceback (most recent call last):
#   File "/content/NLP-DSIMC/RUN.py", line 355, in <module>
#     main()
#   File "/content/NLP-DSIMC/RUN.py", line 351, in main
#     args.func(args)
#   File "/content/NLP-DSIMC/RUN.py", line 254, in cmd_all
#     cmd_train_marbert(args)
#   File "/content/NLP-DSIMC/RUN.py", line 114, in cmd_train_marbert
#     ops.train(train_df, val_df, classes, ARTIFACTS_DIR)
#   File "/content/NLP-DSIMC/Models/MARBERTOps.py", line 165, in train
#     self._trainer = _WeightedTrainer(
#                     ^^^^^^^^^^^^^^^^^
# TypeError: Trainer.__init__() got an unexpected keyword argument 'tokenizer'

# %%
# 7) جمع التقارير والنتائج وتنزيلها على الجهاز
import os, shutil
from google.colab import files

zip_path = "/content/reports_and_results"

# ضغط مجلد النتائج
shutil.make_archive(zip_path, "zip", "/content/outputs")

files.download(zip_path + ".zip")
